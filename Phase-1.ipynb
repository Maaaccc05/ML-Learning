# %% [markdown]
# # NumPy array and basics

# %%
import numpy as np

# %% [markdown]
# ### List vs NumPy Array

# %%
import numpy as np
import time

start = time.time()
py_list = [i*2 for i in range(1000000)]
print("\n List operation time = ", time.time() - start)

start = time.time()
py_npArray = np.arange(1000000) * 2
print("\n Numpy arrays operation time = ", time.time() - start)
# Out:
#  List operation time =  0.0557405948638916
#
#  Numpy arrays operation time =  0.011897802352905273
