# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pandas Series
#
# A series is a one dimentional labeled array capable of holding any data type. The axis lables are collectively called index

# %%
labels = ['a', 'b', 'c']
list = [10, 20, 30]
arr = np.array([10,20,30])
dict = {1:10, 2:20, 3:30}

# %%
pd.Series(list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# # DataFrames
# When You combine multiple series together then it's called as Dataframes

# %% [markdown]
# Creating DataFrame

# %%
data = {
    'Name': ['Mac', 'Kam', 'Sak', 'Bo'],
    'Age': [21, 22, 20, 25],
    'City': ['In', 'In', 'Cam', 'Cam'],
    'Salary': [2000000, 30000, 40000, 50000]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#   Name  Age City   Salary
# 0  Mac   21   In  2000000
# 1  Kam   22   In    30000
# 2  Sak   20  Cam    40000
# 3   Bo   25  Cam    50000

# %%
data_list = [
    ['Macc', 20, 'In', 20000000],
    ['Sak', 19, 'Cam', 3000000],
    ['Kam', 22, 'In', 900000],
    ['Bo', 25, 'Cam', 1000000]
]

df2 = pd.DataFrame(data_list)
columns = ["Name", "Age","City", "Salary"]
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#    Name  Age City    Salary
# 0  Macc   20   In  20000000
# 1   Sak   19  Cam   3000000
# 2   Kam   22   In    900000
# 3    Bo   25  Cam   1000000

# %%
df2
# Out:
#    Name  Age City    Salary
# 0  Macc   20   In  20000000
# 1   Sak   19  Cam   3000000
# 2   Kam   22   In    900000
# 3    Bo   25  Cam   1000000

# %% [markdown]
# Selection and indexing in columns

# %%
df2[['City','Name']]
# Out:
#   City  Name
# 0   In  Macc
# 1  Cam   Sak
# 2   In   Kam
# 3  Cam    Bo

# %% [markdown]
# Creating new Column

# %%
df2["designation"] = ["doc", "eng", "doc", "eng"]
df2
# Out:
#    Name  Age City    Salary designation
# 0  Macc   20   In  20000000         doc
# 1   Sak   19  Cam   3000000         eng
# 2   Kam   22   In    900000         doc
# 3    Bo   25  Cam   1000000         eng

# %% [markdown]
# Deleting Column

# %%
# df2.drop('designation', axis = 1, inplace=True)

# %%
df2
# Out:
#    Name  Age City    Salary
# 0  Macc   20   In  20000000
# 1   Sak   19  Cam   3000000
# 2   Kam   22   In    900000
# 3    Bo   25  Cam   1000000

# %% [markdown]
# Selecting Rows

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age City    Salary
# 0  Macc   20   In  20000000
# 1   Sak   19  Cam   3000000

# %%
df2.iloc[3]
# Out:
# Name           Bo
# Age            25
# City          Cam
# Salary    1000000
# Name: 3, dtype: object
