# %% [markdown]
# # Main Interface
# ## sub
# ### 3rd sub
#
# ---

# %%
print("Again")
# Out:
# Again

# %% [markdown]
# #### Remove Rows in Numpy Array that Contains Non-Numeric Values

# %%
import numpy as np

arr = np.array([[1,2,3],
                [4, mac.kam, kam.mac]])

rmv = arr[np.isfinite(arr).all(axis=1)]

print(rmv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import numpy as np
#       3 arr = np.array([[1,2,3],
# ----> 4                 [4, mac.kam, kam.mac]])
#       6 rmv = arr[np.isfinite(arr).all(axis=1)]
#       8 print(rmv)
#
# NameError: name 'mac' is not defined
